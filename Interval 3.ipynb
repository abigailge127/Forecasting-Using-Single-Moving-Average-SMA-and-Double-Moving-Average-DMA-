# %% [markdown]
# ## Import Library Yang Dibutuhkan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Mengambil Data

# %%
data = pd.read_csv("Populasi Sapi Potong Tahun 2009-2020.csv", index_col = 0)
data #menampilkan data
# Out:
#        KabPacitan  KabPonorogo  Trenggalek  Tulungagung  Blitar  Kediri  \
# Tahun
# 2009        57783        61101       29806        95218  139542  114751
# 2010        61612        63995       30980        99836  144790  123954
# 2011        86138        89148       42560       129678  189378  268139
# 2012        94735        84315       43411       129549  200008  287943
# 2013        76546        84751       29906        91789  132934  181727
# 2014        81954        84514       31431        98987  135592  192631
# 2015        83659        81807       32668       104824  139372  202263
# 2016        84393        82102       33887       111016  141347  212376
# 2017        86611        81823       34515       114556  148414  223216
# 2018        88633        83248       35853       122652  156386  230020
# 2019        91339        82995       37315       130316  151164  232567
# 2020        91039        84813       37901       137095  151720  232802
# ...

# %%
#menampilkan informasi data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14 entries, 2009 to 2022
# Data columns (total 38 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   KabPacitan       14 non-null     int64
#  1   KabPonorogo      14 non-null     int64
#  2   Trenggalek       14 non-null     int64
#  3   Tulungagung      14 non-null     int64
#  4   Blitar           14 non-null     int64
#  5   Kediri           14 non-null     int64
#  6   Malang           14 non-null     int64
#  7   Lumajang         14 non-null     int64
#  8   Jember           14 non-null     int64
#  9   Banyuwangi       14 non-null     int64
#  10  Bondowoso        14 non-null     int64
#  11  Situbondo        14 non-null     int64
#  12  Probolinggo      14 non-null     int64
#  13  Pasuruan         14 non-null     int64
#  14  Sidoarjo         14 non-null     int64
#  15  Mojokerto        14 non-null     int64
#  16  Jombang          14 non-null     int64
# ...

# %%
#menghitung jumlah data yang memiliki nilai kosong
data.isnull().sum()
# Out:
# KabPacitan         0
# KabPonorogo        0
# Trenggalek         0
# Tulungagung        0
# Blitar             0
# Kediri             0
# Malang             0
# Lumajang           0
# Jember             0
# Banyuwangi         0
# Bondowoso          0
# Situbondo          0
# Probolinggo        0
# Pasuruan           0
# Sidoarjo           0
# Mojokerto          0
# Jombang            0
# Nganjuk            0
# Madiun             0
# Magetan            0
# Ngawi              0
# Bojonegoro         0
# Tuban              0
# Lamongan           0
# Gresik             0
# Bangkalan          0
# Sampang            0
# Pamekasan          0
# Sumenep            0
# KediriKota         0
# BlitarKota         0
# MalangKota         0
# Probolinggokota    0
# PasuruanKota       0
# MojokertoKota      0
# MadiunKota         0
# Surabaya           0
# Batu               0
# dtype: int64

# %%
#melihat pola data
plt.figure(figsize=(10,5))
plt.grid(True)
plt.title('Populasi Sapi Potong')
plt.legend(loc=2)

print ("Pola populasi sapi potong pada Kab. Pacitan - Line Blue")
print ("Pola populasi sapi potong pada Kab. Ponorogo - Line Orange")
print ("Pola populasi sapi potong pada Trenggalek - Line Green")
print ("Pola populasi sapi potong pada Tulungaung - Line Red")
print ("Pola populasi sapi potong pada Blitar - Line Purple")


plt.plot(data ['KabPacitan'], label = 'Kab. Pacitan')
plt.plot(data ['KabPonorogo'], label = 'Kab. Ponorogo')
plt.plot(data ['Trenggalek'], label = 'Trenggalek')
plt.plot(data ['Blitar'])
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Pola populasi sapi potong pada Kab. Pacitan - Line Blue
# Pola populasi sapi potong pada Kab. Ponorogo - Line Orange
# Pola populasi sapi potong pada Trenggalek - Line Green
# Pola populasi sapi potong pada Tulungaung - Line Red
# Pola populasi sapi potong pada Blitar - Line Purple

# %%
data_SMA = data
data_DMA = data

# %% [markdown]
# ## Single Moviing Average

# %%
periode = [3]
for i in periode:
    data_SMA['{}_MA_singlepacitan'.format(i)]= data['KabPacitan'].rolling(window=i).mean()
    data_SMA['{}_MA_singleponorogo'.format(i)]= data['KabPonorogo'].rolling(window=i).mean()
    data_SMA['{}_MA_singletrenggalek'.format(i)]= data['Trenggalek'].rolling(window=i).mean()
    data_SMA['{}_MA_singletulungagung'.format(i)]= data['Tulungagung'].rolling(window=i).mean()
    data_SMA['{}_MA_singleblitar'.format(i)]= data['Blitar'].rolling(window=i).mean()
    data_SMA['{}_MA_singlekediri'.format(i)]= data['Kediri'].rolling(window=i).mean()
    data_SMA['{}_MA_singlemalang'.format(i)]= data['Malang'].rolling(window=i).mean()
    data_SMA['{}_MA_singlelumajang'.format(i)]= data['Lumajang'].rolling(window=i).mean()
    data_SMA['{}_MA_singlejember'.format(i)]= data['Jember'].rolling(window=i).mean()
    data_SMA['{}_MA_singlebanyuwangi'.format(i)]= data['Banyuwangi'].rolling(window=i).mean()
    data_SMA['{}_MA_singlebondowoso'.format(i)]= data['Bondowoso'].rolling(window=i).mean()
    data_SMA['{}_MA_singlesitubondo'.format(i)]= data['Situbondo'].rolling(window=i).mean()
    data_SMA['{}_MA_singleprobolinggo'.format(i)]= data['Probolinggo'].rolling(window=i).mean()
    data_SMA['{}_MA_singlepasuruan'.format(i)]= data['Pasuruan'].rolling(window=i).mean()
    data_SMA['{}_MA_singlesidoarjo'.format(i)]= data['Sidoarjo'].rolling(window=i).mean()
    data_SMA['{}_MA_singlemojokerto'.format(i)]= data['Mojokerto'].rolling(window=i).mean()
    data_SMA['{}_MA_singlejombang'.format(i)]= data['Jombang'].rolling(window=i).mean()
    data_SMA['{}_MA_singlenganjuk'.format(i)]= data['Nganjuk'].rolling(window=i).mean()
    data_SMA['{}_MA_singlemadiun'.format(i)]= data['Madiun'].rolling(window=i).mean()
    data_SMA['{}_MA_singlemagetan'.format(i)]= data['Magetan'].rolling(window=i).mean()
    data_SMA['{}_MA_singlengawi'.format(i)]= data['Ngawi'].rolling(window=i).mean()
    data_SMA['{}_MA_singlebojonegoro'.format(i)]= data['Bojonegoro'].rolling(window=i).mean()
    data_SMA['{}_MA_singletuban'.format(i)]= data['Tuban'].rolling(window=i).mean()
    data_SMA['{}_MA_singlelamongan'.format(i)]= data['Lamongan'].rolling(window=i).mean()
    data_SMA['{}_MA_singlegresik'.format(i)]= data['Gresik'].rolling(window=i).mean()
    data_SMA['{}_MA_singlebangkalan'.format(i)]= data['Bangkalan'].rolling(window=i).mean()
    data_SMA['{}_MA_singlesampang'.format(i)]= data['Sampang'].rolling(window=i).mean()
    data_SMA['{}_MA_singlepamekasan'.format(i)]= data['Pamekasan'].rolling(window=i).mean()
    data_SMA['{}_MA_singlesumenep'.format(i)]= data['Sumenep'].rolling(window=i).mean()
    data_SMA['{}_MA_singlekediriKota'.format(i)]= data['KediriKota'].rolling(window=i).mean()
    data_SMA['{}_MA_singleblitarKota'.format(i)]= data['BlitarKota'].rolling(window=i).mean()
    data_SMA['{}_MA_singlemalangKota'.format(i)]= data['MalangKota'].rolling(window=i).mean()
    data_SMA['{}_MA_singleprobolinggoKota'.format(i)]= data['Probolinggokota'].rolling(window=i).mean()
    data_SMA['{}_MA_singlepasuruanKota'.format(i)]= data['PasuruanKota'].rolling(window=i).mean()
    data_SMA['{}_MA_singlemojokertoKota'.format(i)]= data['MojokertoKota'].rolling(window=i).mean()
    data_SMA['{}_MA_singlemadiunKota'.format(i)]= data['MadiunKota'].rolling(window=i).mean()
    data_SMA['{}_MA_singlesurabaya'.format(i)]= data['Surabaya'].rolling(window=i).mean()
    data_SMA['{}_MA_singlebatu'.format(i)]= data['Batu'].rolling(window=i).mean()
data_SMA
# Out:
#         KabPacitan  KabPonorogo  Trenggalek  Tulungagung    Blitar    Kediri  \
# Tahun
# 2009.0     57783.0      61101.0     29806.0      95218.0  139542.0  114751.0
# 2010.0     61612.0      63995.0     30980.0      99836.0  144790.0  123954.0
# 2011.0     86138.0      89148.0     42560.0     129678.0  189378.0  268139.0
# 2012.0     94735.0      84315.0     43411.0     129549.0  200008.0  287943.0
# 2013.0     76546.0      84751.0     29906.0      91789.0  132934.0  181727.0
# 2014.0     81954.0      84514.0     31431.0      98987.0  135592.0  192631.0
# 2015.0     83659.0      81807.0     32668.0     104824.0  139372.0  202263.0
# 2016.0     84393.0      82102.0     33887.0     111016.0  141347.0  212376.0
# 2017.0     86611.0      81823.0     34515.0     114556.0  148414.0  223216.0
# 2018.0     88633.0      83248.0     35853.0     122652.0  156386.0  230020.0
# 2019.0     91339.0      82995.0     37315.0     130316.0  151164.0  232567.0
# ...

# %% [markdown]
# ## Double Moving Average

# %%
periode = [3] 

for i in periode:
    single_ma = data['KabPacitan'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleKabPacitan'.format(i)]= single_ma.rolling(window=i).mean()
    
    single_ma1 = data['KabPonorogo'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleKabPonorogo'.format(i)]= single_ma1.rolling(window=i).mean()
    
    single_ma2 = data['Trenggalek'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleTrenggalek'.format(i)]= single_ma2.rolling(window=i).mean()
    
    single_ma3 = data['Tulungagung'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleTulungagung'.format(i)]= single_ma3.rolling(window=i).mean()
    
    single_ma4 = data['Blitar'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleBlitar'.format(i)]= single_ma4.rolling(window=i).mean()
    
    single_ma5 = data['Kediri'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleKediri'.format(i)]= single_ma5.rolling(window=i).mean()
    
    single_ma6 = data['Malang'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleMalang'.format(i)]= single_ma6.rolling(window=i).mean()
    
    single_ma7 = data['Lumajang'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleLumajang'.format(i)]= single_ma7.rolling(window=i).mean()
    
    single_ma8 = data['Jember'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleJember'.format(i)]= single_ma8.rolling(window=i).mean()
    
    single_ma9 = data['Banyuwangi'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleBanyuwangi'.format(i)]= single_ma9.rolling(window=i).mean()
    
    single_ma10 = data['Bondowoso'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleBondowoso'.format(i)]= single_ma10.rolling(window=i).mean()
    
    single_ma11 = data['Situbondo'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleSitubondo'.format(i)]= single_ma11.rolling(window=i).mean()
    
    single_ma12 = data['Probolinggo'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleProbolinggo'.format(i)]= single_ma12.rolling(window=i).mean()
    
    single_ma13 = data['Pasuruan'].rolling(window=i).mean()
    data_DMA['{}_MA_doublePasuruan'.format(i)]= single_ma13.rolling(window=i).mean()
    
    single_ma14 = data['Sidoarjo'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleSidoarjo'.format(i)]= single_ma14.rolling(window=i).mean()
    
    single_ma15 = data['Mojokerto'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleMojokerto'.format(i)]= single_ma15.rolling(window=i).mean()
    
    single_ma16 = data['Jombang'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleJombang'.format(i)]= single_ma16.rolling(window=i).mean()
    
    single_ma17 = data['Nganjuk'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleNganjuk'.format(i)]= single_ma17.rolling(window=i).mean()
    
    single_ma18 = data['Madiun'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleMadiun'.format(i)]= single_ma18.rolling(window=i).mean()
    
    single_ma19 = data['Magetan'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleMagetan'.format(i)]= single_ma19.rolling(window=i).mean()
    
    single_ma20 = data['Ngawi'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleNgawi'.format(i)]= single_ma20.rolling(window=i).mean()
    
    single_ma21 = data['Bojonegoro'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleBojonegoro'.format(i)]= single_ma21.rolling(window=i).mean()
    
    single_ma22 = data['Tuban'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleTuban'.format(i)]= single_ma22.rolling(window=i).mean()
    
    single_ma23 = data['Lamongan'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleLamongan'.format(i)]= single_ma23.rolling(window=i).mean()
    
    single_ma24 = data['Gresik'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleGresik'.format(i)]= single_ma24.rolling(window=i).mean()
    
    single_ma25 = data['Bangkalan'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleBangkalan'.format(i)]= single_ma25.rolling(window=i).mean()
    
    single_ma26 = data['Sampang'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleSampang'.format(i)]= single_ma26.rolling(window=i).mean()
    
    single_ma27 = data['Pamekasan'].rolling(window=i).mean()
    data_DMA['{}_MA_doublePamekasan'.format(i)]= single_ma27.rolling(window=i).mean()
    
    single_ma28 = data['Sumenep'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleSumenep'.format(i)]= single_ma28.rolling(window=i).mean()
    
    single_ma29 = data['KediriKota'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleKediriKota'.format(i)]= single_ma29.rolling(window=i).mean()

    single_ma30 = data['BlitarKota'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleBlitarKota'.format(i)]= single_ma30.rolling(window=i).mean()
    
    single_ma31 = data['MalangKota'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleMalangKota'.format(i)]= single_ma31.rolling(window=i).mean()
    
    single_ma32 = data['Probolinggokota'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleProbolinggoKota'.format(i)]= single_ma32.rolling(window=i).mean()
    
    single_ma33 = data['PasuruanKota'].rolling(window=i).mean()
    data_DMA['{}_MA_doublePasuruanKota'.format(i)]= single_ma33.rolling(window=i).mean()
    
    single_ma34 = data['MojokertoKota'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleMojokertoKota'.format(i)]= single_ma34.rolling(window=i).mean()
    
    single_ma35 = data['MadiunKota'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleMadiunKota'.format(i)]= single_ma35.rolling(window=i).mean()
    
    single_ma36 = data['Surabaya'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleSurabaya'.format(i)]= single_ma36.rolling(window=i).mean()
    
    single_ma37 = data['Batu'].rolling(window=i).mean()
    data_DMA['{}_MA_doubleBatu'.format(i)]= single_ma37.rolling(window=i).mean()
    
#data_DMA.drop(['2_MA_single','3_MA_single','4_MA_single','5_MA_single'],axis=1,inplace=True)
data_DMA
# Out:
#         KabPacitan  KabPonorogo  Trenggalek  Tulungagung    Blitar    Kediri  \
# Tahun
# 2009.0     57783.0      61101.0     29806.0      95218.0  139542.0  114751.0
# 2010.0     61612.0      63995.0     30980.0      99836.0  144790.0  123954.0
# 2011.0     86138.0      89148.0     42560.0     129678.0  189378.0  268139.0
# 2012.0     94735.0      84315.0     43411.0     129549.0  200008.0  287943.0
# 2013.0     76546.0      84751.0     29906.0      91789.0  132934.0  181727.0
# 2014.0     81954.0      84514.0     31431.0      98987.0  135592.0  192631.0
# 2015.0     83659.0      81807.0     32668.0     104824.0  139372.0  202263.0
# 2016.0     84393.0      82102.0     33887.0     111016.0  141347.0  212376.0
# 2017.0     86611.0      81823.0     34515.0     114556.0  148414.0  223216.0
# 2018.0     88633.0      83248.0     35853.0     122652.0  156386.0  230020.0
# 2019.0     91339.0      82995.0     37315.0     130316.0  151164.0  232567.0
# ...

# %%
#eksport data setelah diolah ke dalam bentuk csv
data_DMA.to_csv('Hasil_DMA.csv', index=False)
Hasil_DMA = pd.read_csv('Hasil_DMA.csv', encoding = 'latin1')
Hasil_DMA
# Out:
#     KabPacitan  KabPonorogo  Trenggalek  Tulungagung    Blitar    Kediri  \
# 0      57783.0      61101.0     29806.0      95218.0  139542.0  114751.0
# 1      61612.0      63995.0     30980.0      99836.0  144790.0  123954.0
# 2      86138.0      89148.0     42560.0     129678.0  189378.0  268139.0
# 3      94735.0      84315.0     43411.0     129549.0  200008.0  287943.0
# 4      76546.0      84751.0     29906.0      91789.0  132934.0  181727.0
# 5      81954.0      84514.0     31431.0      98987.0  135592.0  192631.0
# 6      83659.0      81807.0     32668.0     104824.0  139372.0  202263.0
# 7      84393.0      82102.0     33887.0     111016.0  141347.0  212376.0
# 8      86611.0      81823.0     34515.0     114556.0  148414.0  223216.0
# 9      88633.0      83248.0     35853.0     122652.0  156386.0  230020.0
# 10     91339.0      82995.0     37315.0     130316.0  151164.0  232567.0
# 11     91039.0      84813.0     37901.0     137095.0  151720.0  232802.0
# ...

# %% [markdown]
# ## AT

# %%
import math

def AT (SMA, DMA):
    DMA_AT = []

    for i in range (len(Hasil_DMA)):    
        TES = 0
        if math.isnan(Hasil_DMA['3_MA_single'+SMA][i]):
            continue
    
        if math.isnan(Hasil_DMA['3_MA_double'+DMA][i]):
            continue
    
        TES = 2 * Hasil_DMA['3_MA_single'+SMA][i] - Hasil_DMA['3_MA_double'+DMA][i]
    
        #print (TES)
    
        DMA_AT.append(TES)
    return DMA_AT  

    print (TES)

# %%
dataforAT = {'AT_KabPacitan' : AT ("pacitan", "KabPacitan"),
        'AT_KabPonorogo' : AT ("ponorogo", "KabPonorogo"),
        'AT_Trenggalek' : AT ("trenggalek", "Trenggalek"),
        'AT_Tulungagung' : AT ("tulungagung", "Tulungagung"),
        'AT_Blitar' : AT ("blitar", "Blitar"),
        'AT_Kediri' : AT ("kediri", "Kediri"),
        'AT_Malang' : AT ("malang", "Malang"),
        'AT_Lumajang' : AT ("lumajang", "Lumajang"),
        'AT_Jember' : AT ("jember", "Jember"),
        'AT_Banyuwangi' : AT ("banyuwangi", "Banyuwangi"),
        'AT_Bondowoso' : AT ("bondowoso", "Bondowoso"),
        'AT_Situbondo' : AT ("situbondo", "Situbondo"),
        'AT_Probolinggo' : AT ("probolinggo", "Probolinggo"),
        'AT_Pasuruan' : AT ("pasuruan", "Pasuruan"),
        'AT_Sidoarjo' : AT ("sidoarjo", "Sidoarjo"),
        'AT_Mojokerto' : AT ("mojokerto", "Mojokerto"),
        'AT_Jombang' : AT ("jombang", "Jombang"),
        'AT_Nganjuk' : AT ("nganjuk", "Nganjuk"),
        'AT_Madiun' : AT ("madiun", "Madiun"),
        'AT_Magetan' : AT ("magetan", "Magetan"),
        'AT_Ngawi' : AT ("ngawi", "Ngawi"),
        'AT_Bojonegoro' : AT ("bojonegoro", "Bojonegoro"),
        'AT_Tuban' : AT ("tuban", "Tuban"),
        'AT_Lamongan' : AT ("lamongan", "Lamongan"),
        'AT_Gresik' : AT ("gresik", "Gresik"),
        'AT_Bangkalan': AT ("bangkalan", "Bangkalan"),
        'AT_Sampang' : AT ("sampang", "Sampang"),
        'AT_Pamekasan' : AT ("pamekasan", "Pamekasan"),
        'AT_Sumenep' : AT ("sumenep", "Sumenep"),
        'AT_KediriKota' : AT ("kediriKota", "KediriKota"),
        'AT_BlitarKota' : AT ("blitarKota", "BlitarKota"),
        'AT_MalangKota' : AT ("malangKota", "MalangKota"),
        'AT_ProbolinggoKota' : AT ("probolinggoKota", "ProbolinggoKota"),
        'AT_PasuruanKota' : AT ("pasuruanKota" , "PasuruanKota"),
        'AT_MojokertoKota' : AT ("mojokertoKota", "MojokertoKota"),
        'AT_MadiunKota' : AT ("madiunKota", "MadiunKota"),
        'AT_Surabaya' : AT ("surabaya", "Surabaya"),
        'AT_Batu' : AT ("batu", "Batu")
       }
    
    
data_AT = pd.DataFrame(dataforAT)    
data_AT
# Out:
#    AT_KabPacitan  AT_KabPonorogo  AT_Trenggalek  AT_Tulungagung  \
# 0   93230.777778    93263.111111   39898.666667   119031.666667
# 1   85141.222222    85803.111111   32323.555556    99060.666667
# 2   77793.444444    82618.444444   27711.111111    89628.777778
# 3   83848.444444    81940.333333   32353.000000   106467.777778
# 4   86794.444444    81018.333333   34817.666667   115728.111111
# 5   88168.444444    82412.222222   35802.111111   121766.333333
# 6   90957.222222    83047.222222   37010.000000   128777.777778
# 7   92092.777778    84449.000000   38156.333333   137174.111111
# 8   94896.222222    85388.666667   39058.666667   144830.333333
# 9   97376.333333    86595.555556   39861.111111   152211.111111
#
#        AT_Blitar      AT_Kediri      AT_Malang    AT_Lumajang      AT_Jember  \
# 0  178190.444444  278018.333333  238702.222222  200594.000000  306824.222222
# 1  142908.222222  210406.666667  208492.000000  177289.333333  246268.555556
# ...

# %% [markdown]
# ## BT

# %%
def BT (SMA, DMA):
    DMA_BT = []

    for i in range (len(Hasil_DMA)):    
        TES = 0
        if math.isnan(Hasil_DMA['3_MA_single'+SMA][i]):
            continue
    
        if math.isnan(Hasil_DMA['3_MA_double'+DMA][i]):
            continue
    
        TES = (2/(3-1)) * (Hasil_DMA['3_MA_single'+SMA][i] - Hasil_DMA['3_MA_double'+DMA][i])
    
    #print (TES)
    
        DMA_BT.append(TES)
    return DMA_BT

# %%
dataforBT = {'BT_KabPacitan' : BT ("pacitan", "KabPacitan"),
        'BT_KabPonorogo' : BT ("ponorogo", "KabPonorogo"),
        'BT_Trenggalek' : BT ("trenggalek", "Trenggalek"),
        'BT_Tulungagung' : BT ("tulungagung", "Tulungagung"),
        'BT_Blitar' : BT ("blitar", "Blitar"),
        'BT_Kediri' : BT ("kediri", "Kediri"),
        'BT_Malang' : BT ("malang", "Malang"),
        'BT_Lumajang' : BT ("lumajang", "Lumajang"),
        'BT_Jember' : BT ("jember", "Jember"),
        'BT_Banyuwangi' : BT ("banyuwangi", "Banyuwangi"),
        'BT_Bondowoso' : BT ("bondowoso", "Bondowoso"),
        'BT_Situbondo' : BT ("situbondo", "Situbondo"),
        'BT_Probolinggo' : BT ("probolinggo", "Probolinggo"),
        'BT_Pasuruan' : BT ("pasuruan", "Pasuruan"),
        'BT_Sidoarjo' : BT ("sidoarjo", "Sidoarjo"),
        'BT_Mojokerto' : BT ("mojokerto", "Mojokerto"),
        'BT_Jombang' : BT ("jombang", "Jombang"),
        'BT_Nganjuk' : BT ("nganjuk", "Nganjuk"),
        'BT_Madiun' : BT ("madiun", "Madiun"),
        'BT_Magetan' : BT ("magetan", "Magetan"),
        'BT_Ngawi' : BT ("ngawi", "Ngawi"),
        'BT_Bojonegoro' : BT ("bojonegoro", "Bojonegoro"),
        'BT_Tuban' : BT ("tuban", "Tuban"),
        'BT_Lamongan' : BT ("lamongan", "Lamongan"),
        'BT_Gresik' : BT ("gresik", "Gresik"),
        'BT_Bangkalan': BT ("bangkalan", "Bangkalan"),
        'BT_Sampang' : BT ("sampang", "Sampang"),
        'BT_Pamekasan' : BT ("pamekasan", "Pamekasan"),
        'BT_Sumenep' : BT ("sumenep", "Sumenep"),
        'BT_KediriKota' : BT ("kediriKota", "KediriKota"),
        'BT_BlitarKota' : BT ("blitarKota", "BlitarKota"),
        'BT_MalangKota' : BT ("malangKota", "MalangKota"),
        'BT_ProbolinggoKota' : BT ("probolinggoKota", "ProbolinggoKota"),
        'BT_PasuruanKota' : BT ("pasuruanKota" , "PasuruanKota"),
        'BT_MojokertoKota' : BT ("mojokertoKota", "MojokertoKota"),
        'BT_MadiunKota' : BT ("madiunKota", "MadiunKota"),
        'BT_Surabaya' : BT ("surabaya", "Surabaya"),
        'BT_Batu' : BT ("batu", "Batu")
       }
    
data_BT = pd.DataFrame(dataforBT)    
data_BT
# Out:
#    BT_KabPacitan  BT_KabPonorogo  BT_Trenggalek  BT_Tulungagung     BT_Blitar  \
# 0    7424.444444     7191.777778    1273.000000     2026.333333   4083.777778
# 1     729.555556     1276.444444   -2592.444444    -7714.333333 -13269.777778
# 2   -2926.222222    -1072.222222   -3623.888889    -8904.555556 -19450.888889
# 3     513.111111     -867.333333    -309.000000     1525.444444  -4867.777778
# 4    1906.777778     -892.333333    1127.666667     5596.111111   3784.111111
# 5    1622.777778       21.222222    1050.444444     5691.666667   5205.555556
# 6    2096.222222      358.555556    1115.666667     6269.777778   4072.000000
# 7    1755.777778      763.666667    1133.333333     7153.111111   1825.444444
# 8    2118.888889      880.666667    1040.000000     7426.333333   -200.888889
# 9    2327.666667      999.555556     936.111111     7399.444444    778.111111
#
#       BT_Kediri     BT_Malang  BT_Lumajang     BT_Jember  BT_Banyuwangi  ...  \
# ...

# %%
#menggabungkan data dari dua data frame
a = data_AT
b = data_BT

data_ATBT = pd.concat([a,b], axis=1)
data_ATBT
# Out:
#    AT_KabPacitan  AT_KabPonorogo  AT_Trenggalek  AT_Tulungagung  \
# 0   93230.777778    93263.111111   39898.666667   119031.666667
# 1   85141.222222    85803.111111   32323.555556    99060.666667
# 2   77793.444444    82618.444444   27711.111111    89628.777778
# 3   83848.444444    81940.333333   32353.000000   106467.777778
# 4   86794.444444    81018.333333   34817.666667   115728.111111
# 5   88168.444444    82412.222222   35802.111111   121766.333333
# 6   90957.222222    83047.222222   37010.000000   128777.777778
# 7   92092.777778    84449.000000   38156.333333   137174.111111
# 8   94896.222222    85388.666667   39058.666667   144830.333333
# 9   97376.333333    86595.555556   39861.111111   152211.111111
#
#        AT_Blitar      AT_Kediri      AT_Malang    AT_Lumajang      AT_Jember  \
# 0  178190.444444  278018.333333  238702.222222  200594.000000  306824.222222
# 1  142908.222222  210406.666667  208492.000000  177289.333333  246268.555556
# ...

# %% [markdown]
# ## FT

# %%
def FT (AT, BT):
    DMA_FT = []

    for i in range (len(data_ATBT)):    
        TES = 0
        if math.isnan(data_ATBT['AT_'+AT][i]):
            continue
    
        if math.isnan(data_ATBT['BT_'+BT][i]):
            continue
    
        TES = (data_ATBT['AT_'+AT][i] + data_ATBT['BT_'+BT][i])
    
    #print (TES)
    
        DMA_FT.append(TES)
    return DMA_FT  

#print (TES)

# %%
dataforFT = {'Tahun' : ("2014","2015", "2016", "2017", "2018", "2019", "2020", "2021", "2022", "2023"),
        'FT_KabPacitan' : FT ("KabPacitan", "KabPacitan"),
        'FT_KabPonorogo' : FT ("KabPonorogo", "KabPonorogo"),
        'FT_Trenggalek' : FT ("Trenggalek", "Trenggalek"),
        'FT_Tulungagung' : FT ("Tulungagung", "Tulungagung"),
        'FT_Blitar' : FT ("Blitar", "Blitar"),
        'FT_Kediri' : FT ("Kediri", "Kediri"),
        'FT_Malang' : FT ("Malang", "Malang"),
        'FT_Lumajang' : FT ("Lumajang", "Lumajang"),
        'FT_Jember' : FT ("Jember", "Jember"),
        'FT_Banyuwangi' : FT ("Banyuwangi", "Banyuwangi"),
        'FT_Bondowoso' : FT ("Bondowoso", "Bondowoso"),
        'FT_Situbondo' : FT ("Situbondo", "Situbondo"),
        'FT_Probolinggo' : FT ("Probolinggo", "Probolinggo"),
        'FT_Pasuruan' : FT ("Pasuruan", "Pasuruan"),
        'FT_Sidoarjo' : FT ("Sidoarjo", "Sidoarjo"),
        'FT_Mojokerto' : FT ("Mojokerto", "Mojokerto"),
        'FT_Jombang' : FT ("Jombang", "Jombang"),
        'FT_Nganjuk' : FT ("Nganjuk", "Nganjuk"),
        'FT_Madiun' : FT ("Madiun", "Madiun"),
        'FT_Magetan' : FT ("Magetan", "Magetan"),
        'FT_Ngawi' : FT ("Ngawi", "Ngawi"),
        'FT_Bojonegoro' : FT ("Bojonegoro", "Bojonegoro"),
        'FT_Tuban' : FT ("Tuban", "Tuban"),
        'FT_Lamongan' : FT ("Lamongan", "Lamongan"),
        'FT_Gresik' : FT ("Gresik", "Gresik"),
        'FT_Bangkalan': FT ("Bangkalan", "Bangkalan"),
        'FT_Sampang' : FT ("Sampang", "Sampang"),
        'FT_Pamekasan' : FT ("Pamekasan", "Pamekasan"),
        'FT_Sumenep' : FT ("Sumenep", "Sumenep"),
        'FT_KediriKota' : FT ("KediriKota", "KediriKota"),
        'FT_BlitarKota' : FT ("BlitarKota", "BlitarKota"),
        'FT_MalangKota' : FT ("MalangKota", "MalangKota"),
        'FT_ProbolinggoKota' : FT ("ProbolinggoKota", "ProbolinggoKota"),
        'FT_PasuruanKota' : FT ("PasuruanKota" , "PasuruanKota"),
        'FT_MojokertoKota' : FT ("MojokertoKota", "MojokertoKota"),
        'FT_MadiunKota' : FT ("MadiunKota", "MadiunKota"),
        'FT_Surabaya' : FT ("Surabaya", "Surabaya"),
        'FT_Batu' : FT ("Batu", "Batu")
       }
    
data_FT = pd.DataFrame(dataforFT)    
data_FT
# Out:
#   Tahun  FT_KabPacitan  FT_KabPonorogo  FT_Trenggalek  FT_Tulungagung  \
# 0  2014  100655.222222   100454.888889   41171.666667   121058.000000
# 1  2015   85870.777778    87079.555556   29731.111111    91346.333333
# 2  2016   74867.222222    81546.222222   24087.222222    80724.222222
# 3  2017   84361.555556    81073.000000   32044.000000   107993.222222
# 4  2018   88701.222222    80126.000000   35945.333333   121324.222222
# 5  2019   89791.222222    82433.444444   36852.555556   127458.000000
# 6  2020   93053.444444    83405.777778   38125.666667   135047.555556
# 7  2021   93848.555556    85212.666667   39289.666667   144327.222222
# 8  2022   97015.111111    86269.333333   40098.666667   152256.666667
# 9  2023   99704.000000    87595.111111   40797.222222   159610.555556
#
#        FT_Blitar      FT_Kediri      FT_Malang    FT_Lumajang      FT_Jember  \
# 0  182274.222222  310100.333333  258809.111111  209352.000000  316260.777778
# ...

# %%
#menghapus baris terakhir
dataFT = data_FT.drop(labels=[9], axis=0)

# %%
#ekspor data ke dalam bentuk csv
dataFT.to_csv('Hasil_FT.csv', index=False)
Hasil_FT = pd.read_csv('Hasil_FT.csv', encoding = 'latin1')
Hasil_FT
# Out:
#    Tahun  FT_KabPacitan  FT_KabPonorogo  FT_Trenggalek  FT_Tulungagung  \
# 0   2014  100655.222222   100454.888889   41171.666667   121058.000000
# 1   2015   85870.777778    87079.555556   29731.111111    91346.333333
# 2   2016   74867.222222    81546.222222   24087.222222    80724.222222
# 3   2017   84361.555556    81073.000000   32044.000000   107993.222222
# 4   2018   88701.222222    80126.000000   35945.333333   121324.222222
# 5   2019   89791.222222    82433.444444   36852.555556   127458.000000
# 6   2020   93053.444444    83405.777778   38125.666667   135047.555556
# 7   2021   93848.555556    85212.666667   39289.666667   144327.222222
# 8   2022   97015.111111    86269.333333   40098.666667   152256.666667
#
#        FT_Blitar      FT_Kediri      FT_Malang    FT_Lumajang      FT_Jember  \
# 0  182274.222222  310100.333333  258809.111111  209352.000000  316260.777778
# 1  129638.444444  200046.333333  207202.666667  171961.666667  224493.444444
# ...

# %%
#menampilkan hasil peramalan tahun 2022
Hasil_FT.loc[8:8]
# Out:
#    Tahun  FT_KabPacitan  FT_KabPonorogo  FT_Trenggalek  FT_Tulungagung  \
# 8   2022   97015.111111    86269.333333   40098.666667   152256.666667
#
#        FT_Blitar      FT_Kediri  FT_Malang    FT_Lumajang      FT_Jember  ...  \
# 8  151835.888889  237159.777778   249537.0  231397.888889  280162.777778  ...
#
#       FT_Sumenep  FT_KediriKota  FT_BlitarKota  FT_MalangKota  \
# 8  388124.444444    3583.222222    4161.888889    2444.444444
#
#    FT_ProbolinggoKota  FT_PasuruanKota  FT_MojokertoKota  FT_MadiunKota  \
# 8        11426.111111       461.555556         86.111111     171.222222
#
#    FT_Surabaya      FT_Batu
# 8    46.111111  2512.444444
#
# [1 rows x 39 columns]

# %%
dataaktual = pd.read_csv("Populasi Sapi Potong Tahun 2009-2020.csv")
dataaktual
# Out:
#     Tahun  KabPacitan  KabPonorogo  Trenggalek  Tulungagung  Blitar  Kediri  \
# 0    2009       57783        61101       29806        95218  139542  114751
# 1    2010       61612        63995       30980        99836  144790  123954
# 2    2011       86138        89148       42560       129678  189378  268139
# 3    2012       94735        84315       43411       129549  200008  287943
# 4    2013       76546        84751       29906        91789  132934  181727
# 5    2014       81954        84514       31431        98987  135592  192631
# 6    2015       83659        81807       32668       104824  139372  202263
# 7    2016       84393        82102       33887       111016  141347  212376
# 8    2017       86611        81823       34515       114556  148414  223216
# 9    2018       88633        83248       35853       122652  156386  230020
# 10   2019       91339        82995       37315       130316  151164  232567
# ...

# %%
data_aktualformape = dataaktual.drop(labels=[0,1,2,3,4], axis=0) #menghapus kolom
data_aktualformape.to_csv('dataaktualformape.csv', index=False)
dataaktualformape_ = pd.read_csv('dataaktualformape.csv', encoding = 'latin1')
dataaktualformape_
#d = Hasil_FT

#dataformape2 = pd.concat([c,d], axis=1)
#dataformape2
# Out:
#    Tahun  KabPacitan  KabPonorogo  Trenggalek  Tulungagung  Blitar  Kediri  \
# 0   2014       81954        84514       31431        98987  135592  192631
# 1   2015       83659        81807       32668       104824  139372  202263
# 2   2016       84393        82102       33887       111016  141347  212376
# 3   2017       86611        81823       34515       114556  148414  223216
# 4   2018       88633        83248       35853       122652  156386  230020
# 5   2019       91339        82995       37315       130316  151164  232567
# 6   2020       91039        84813       37901       137095  151720  232802
# 7   2021       95954        85716       38840       144801  153829  234177
# 8   2022       98153        86259       40034       152539  155944  240852
#
#    Malang  Lumajang  Jember  ...  Sumenep  KediriKota  BlitarKota  MalangKota  \
# 0  199453    172920  236198  ...   349081        3600        2797        4039
# ...

# %%
#menggabung data
c = dataaktualformape_
d = Hasil_FT

dataformape = pd.concat([c,d], axis=1)
dataformape
# Out:
#    Tahun  KabPacitan  KabPonorogo  Trenggalek  Tulungagung  Blitar  Kediri  \
# 0   2014       81954        84514       31431        98987  135592  192631
# 1   2015       83659        81807       32668       104824  139372  202263
# 2   2016       84393        82102       33887       111016  141347  212376
# 3   2017       86611        81823       34515       114556  148414  223216
# 4   2018       88633        83248       35853       122652  156386  230020
# 5   2019       91339        82995       37315       130316  151164  232567
# 6   2020       91039        84813       37901       137095  151720  232802
# 7   2021       95954        85716       38840       144801  153829  234177
# 8   2022       98153        86259       40034       152539  155944  240852
#
#    Malang  Lumajang  Jember  ...     FT_Sumenep  FT_KediriKota  FT_BlitarKota  \
# 0  199453    172920  236198  ...  381205.444444    5308.555556    2724.111111
# ...

# %% [markdown]
# ## MAPE

# %%
def mape (aktual, prediksi):
    hasil_mape = []

    for i in range (len(dataformape)):    
        TES = 0
        if math.isnan(dataformape[aktual][i]):
            continue
    
        if math.isnan(dataformape['FT_'+prediksi][i]):
            continue
    
        TES = np.abs(((dataformape[aktual][i])-(dataformape['FT_'+prediksi][i]))/(dataformape[aktual][i]))*100
    
    #print (TES)
    
        hasil_mape.append(TES)
    return hasil_mape

# %%
datamape = {'Tahun' : ("2014","2015", "2016", "2017", "2018", "2019", "2020", "2021", "2022"),
            'mape_KabPacitan' : mape ("KabPacitan", "KabPacitan"),
            'mape_KabPonorogo' : mape ("KabPonorogo", "KabPonorogo"),
            'mape_Trenggalek' : mape ("Trenggalek", "Trenggalek"),
            'mape_Tulungagung' : mape ("Tulungagung", "Tulungagung"),
            'mape_Blitar' : mape ("Blitar", "Blitar"),
            'mape_Kediri' : mape ("Kediri", "Kediri"),
            'mape_Malang' : mape ("Malang", "Malang"),
            'mape_Lumajang' : mape ("Lumajang", "Lumajang"),
            'mape_Jember' : mape ("Jember", "Jember"),
            'mape_Banyuwangi' : mape ("Banyuwangi", "Banyuwangi"),
            'mape_Bondowoso' : mape ("Bondowoso", "Bondowoso"),
            'mape_Situbondo' : mape ("Situbondo", "Situbondo"),
            'mape_Probolinggo' : mape ("Probolinggo", "Probolinggo"),
            'mape_Pasuruan' : mape ("Pasuruan", "Pasuruan"),
            'mape_Sidoarjo' : mape ("Sidoarjo", "Sidoarjo"),
            'mape_Mojokerto' : mape ("Mojokerto", "Mojokerto"),
            'mape_Jombang' : mape ("Jombang", "Jombang"),
            'mape_Nganjuk' : mape ("Nganjuk", "Nganjuk"),
            'mape_Madiun' : mape ("Madiun", "Madiun"),
            'mape_Magetan' : mape ("Magetan", "Magetan"),
            'mape_Ngawi' : mape ("Ngawi", "Ngawi"),
            'mape_Bojonegoro' : mape ("Bojonegoro", "Bojonegoro"),
            'mape_Tuban' : mape ("Tuban", "Tuban"),
            'mape_Lamongan' : mape ("Lamongan", "Lamongan"),
            'mape_Gresik' : mape ("Gresik", "Gresik"),
            'mape_Bangkalan': mape ("Bangkalan", "Bangkalan"),
            'mape_Sampang' : mape ("Sampang", "Sampang"),
            'mape_Pamekasan' : mape ("Pamekasan", "Pamekasan"),
            'mape_Sumenep' : mape ("Sumenep", "Sumenep"),
            'mape_KediriKota' : mape ("KediriKota", "KediriKota"),
            'mape_BlitarKota' : mape ("BlitarKota", "BlitarKota"),
            'mape_MalangKota' : mape ("MalangKota", "MalangKota"),
            'mape_ProbolinggoKota' : mape ("Probolinggokota", "ProbolinggoKota"),
            'mape_PasuruanKota' : mape ("PasuruanKota" , "PasuruanKota"),
            'mape_MojokertoKota' : mape ("MojokertoKota", "MojokertoKota"),
            'mape_MadiunKota' : mape ("MadiunKota", "MadiunKota"),
            'mape_Surabaya' : mape ("Surabaya", "Surabaya"),
            'mape_Batu' : mape ("Batu", "Batu")
       }

Hasil_mape = pd.DataFrame(datamape) 
Hasil_mape
# Out:
#   Tahun  mape_KabPacitan  mape_KabPonorogo  mape_Trenggalek  mape_Tulungagung  \
# 0  2014        22.819170         18.861832        30.990636         22.296867
# 1  2015         2.643801          6.445115         8.990109         12.857425
# 2  2016        11.287403          0.676936        28.918989         27.285957
# 3  2017         2.597181          0.916613         7.159206          5.728882
# 4  2018         0.076972          3.750240         0.257533          1.082557
# 5  2019         1.694542          0.676614         1.239299          2.193131
# 6  2020         2.212727          1.659206         0.592772          1.493449
# 7  2021         2.194223          0.587210         1.157741          0.327192
# 8  2022         1.159301          0.011979         0.161529          0.185089
#
#    mape_Blitar  mape_Kediri  mape_Malang  mape_Lumajang  mape_Jember  ...  \
# 0    34.428449    60.981531    29.759448      21.068702    33.896467  ...
# ...

# %%
def totalmape (mape):
    total_mape = (Hasil_mape['mape_'+mape]).mean()  
    
    return total_mape

# %%
totalmape = {'KabPacitan' : (Hasil_mape['mape_KabPacitan'].mean()),
            'KabPonorogo' : (Hasil_mape['mape_KabPonorogo'].mean()),
            'Trenggalek' : (Hasil_mape['mape_Trenggalek'].mean()),
            'Tulungagung' : (Hasil_mape['mape_Tulungagung'].mean()),
            'Blitar' : (Hasil_mape['mape_Blitar'].mean()),
            'Kediri' : (Hasil_mape['mape_Kediri'].mean()),
            'Malang' : (Hasil_mape['mape_Malang'].mean()),
            'Lumajang' : (Hasil_mape['mape_Lumajang'].mean()),
            'Jember' : (Hasil_mape['mape_Jember'].mean()),
            'Banyuwangi' : (Hasil_mape['mape_Banyuwangi'].mean()),
            'Bondowoso' : (Hasil_mape['mape_Bondowoso'].mean()),
            'Situbondo' : (Hasil_mape['mape_Situbondo'].mean()),
            'Probolinggo' : (Hasil_mape['mape_Probolinggo'].mean()),
            'Pasuruan' : (Hasil_mape['mape_Pasuruan'].mean()),
            'Sidoarjo' : (Hasil_mape['mape_Sidoarjo'].mean()),
            'Mojokerto' : (Hasil_mape['mape_Mojokerto'].mean()),
            'Jombang' : (Hasil_mape['mape_Jombang'].mean()),
            'Nganjuk' : (Hasil_mape['mape_Nganjuk'].mean()),
            'Madiun' : (Hasil_mape['mape_Madiun'].mean()),
            'Magetan' : (Hasil_mape['mape_Magetan'].mean()),
            'Ngawi' : (Hasil_mape['mape_Ngawi'].mean()),
            'Bojonegoro' : (Hasil_mape['mape_Bojonegoro'].mean()),
            'Tuban' : (Hasil_mape['mape_Tuban'].mean()),
            'Lamongan' : (Hasil_mape['mape_Lamongan'].mean()),
            'Gresik' : (Hasil_mape['mape_Gresik'].mean()),
            'Bangkalan' : (Hasil_mape['mape_Bangkalan'].mean()),
            'Sampang' : (Hasil_mape['mape_Sampang'].mean()),
            'Pamekasan' : (Hasil_mape['mape_Pamekasan'].mean()),
            'Sumenep' : (Hasil_mape['mape_Sumenep'].mean()),
            'KediriKota' : (Hasil_mape['mape_KediriKota'].mean()),
            'BlitarKota' : (Hasil_mape['mape_BlitarKota'].mean()),
            'MalangKota' : (Hasil_mape['mape_MalangKota'].mean()),
            'ProbolinggoKota' : (Hasil_mape['mape_ProbolinggoKota'].mean()),
            'PasuruanKota' : (Hasil_mape['mape_PasuruanKota'].mean()),
            'MojokertoKota' : (Hasil_mape['mape_MojokertoKota'].mean()),
            'MadiunKota' : (Hasil_mape['mape_MadiunKota'].mean()),
            'Surabaya' : (Hasil_mape['mape_Surabaya'].mean()),
            'Batu' : (Hasil_mape['mape_Batu'].mean())
           }

total_mape = pd.DataFrame(totalmape, index=[0])
total_mape
# Out:
#    KabPacitan  KabPonorogo  Trenggalek  Tulungagung     Blitar     Kediri  \
# 0    5.187258      3.73175    8.829757     8.161172  11.647792  13.670275
#
#      Malang  Lumajang    Jember  Banyuwangi  ...   Sumenep  KediriKota  \
# 0  7.785515  6.703797  9.598799    8.229447  ...  1.736102   22.888491
#
#    BlitarKota  MalangKota  ProbolinggoKota  PasuruanKota  MojokertoKota  \
# 0    7.159049   19.084927         4.725454     24.771636      35.870629
#
#    MadiunKota    Surabaya      Batu
# 0   26.239075  155.530111  7.490393
#
# [1 rows x 38 columns]

# %%
totalmape = total_mape.T #transpose data
hasilakhirmape = totalmape[0].mean()
print ("hasil akhir mape adalah =", hasilakhirmape)
# Out:
# hasil akhir mape adalah = 13.463413326520074

# %% [markdown]
# ## MAD

# %%
def mad (aktual, prediksi):
    hasil_mad = []

    for i in range (len(dataformape)):    
        TES = 0
        if math.isnan(dataformape[aktual][i]):
            continue
    
        if math.isnan(dataformape['FT_'+prediksi][i]):
            continue
    
        TES = np.mean(np.abs((dataformape[aktual][i])-(dataformape['FT_'+prediksi][i])))
    
    #print (TES)
    
        hasil_mad.append(TES)
    return hasil_mad

# %%
datamad = { 'Tahun' : ("2014","2015", "2016", "2017", "2018", "2019", "2020", "2021", "2022"),
            'mad_KabPacitan' : mad ("KabPacitan", "KabPacitan"),
            'mad_KabPonorogo' : mad ("KabPonorogo", "KabPonorogo"),
            'mad_Trenggalek' : mad ("Trenggalek", "Trenggalek"),
            'mad_Tulungagung' : mad ("Tulungagung", "Tulungagung"),
            'mad_Blitar' : mad ("Blitar", "Blitar"),
            'mad_Kediri' : mad ("Kediri", "Kediri"),
            'mad_Malang' : mad ("Malang", "Malang"),
            'mad_Lumajang' : mad ("Lumajang", "Lumajang"),
            'mad_Jember' : mad ("Jember", "Jember"),
            'mad_Banyuwangi' : mad ("Banyuwangi", "Banyuwangi"),
            'mad_Bondowoso' : mad ("Bondowoso", "Bondowoso"),
            'mad_Situbondo' : mad ("Situbondo", "Situbondo"),
            'mad_Probolinggo' : mad ("Probolinggo", "Probolinggo"),
            'mad_Pasuruan' : mad ("Pasuruan", "Pasuruan"),
            'mad_Sidoarjo' : mad ("Sidoarjo", "Sidoarjo"),
            'mad_Mojokerto' : mad ("Mojokerto", "Mojokerto"),
            'mad_Jombang' : mad ("Jombang", "Jombang"),
            'mad_Nganjuk' : mad ("Nganjuk", "Nganjuk"),
            'mad_Madiun' : mad ("Madiun", "Madiun"),
            'mad_Magetan' : mad ("Magetan", "Magetan"),
            'mad_Ngawi' : mad ("Ngawi", "Ngawi"),
            'mad_Bojonegoro' : mad ("Bojonegoro", "Bojonegoro"),
            'mad_Tuban' : mad ("Tuban", "Tuban"),
            'mad_Lamongan' : mad ("Lamongan", "Lamongan"),
            'mad_Gresik' : mad ("Gresik", "Gresik"),
            'mad_Bangkalan': mad ("Bangkalan", "Bangkalan"),
            'mad_Sampang' : mad ("Sampang", "Sampang"),
            'mad_Pamekasan' : mad ("Pamekasan", "Pamekasan"),
            'mad_Sumenep' : mad ("Sumenep", "Sumenep"),
            'mad_KediriKota' : mad ("KediriKota", "KediriKota"),
            'mad_BlitarKota' : mad ("BlitarKota", "BlitarKota"),
            'mad_MalangKota' : mad ("MalangKota", "MalangKota"),
            'mad_ProbolinggoKota' : mad ("Probolinggokota", "ProbolinggoKota"),
            'mad_PasuruanKota' : mad ("PasuruanKota" , "PasuruanKota"),
            'mad_MojokertoKota' : mad ("MojokertoKota", "MojokertoKota"),
            'mad_MadiunKota' : mape ("MadiunKota", "MadiunKota"),
            'mad_Surabaya' : mad ("Surabaya", "Surabaya"),
            'mad_Batu' : mad ("Batu", "Batu")
       }

Hasil_mad = pd.DataFrame(datamad) 
Hasil_mad
# Out:
#   Tahun  mad_KabPacitan  mad_KabPonorogo  mad_Trenggalek  mad_Tulungagung  \
# 0  2014    18701.222222     15940.888889     9740.666667     22071.000000
# 1  2015     2211.777778      5272.555556     2936.888889     13477.666667
# 2  2016     9525.777778       555.777778     9799.777778     30291.777778
# 3  2017     2249.444444       750.000000     2471.000000      6562.777778
# 4  2018       68.222222      3122.000000       92.333333      1327.777778
# 5  2019     1547.777778       561.555556      462.444444      2858.000000
# 6  2020     2014.444444      1407.222222      224.666667      2047.444444
# 7  2021     2105.444444       503.333333      449.666667       473.777778
# 8  2022     1137.888889        10.333333       64.666667       282.333333
#
#      mad_Blitar     mad_Kediri    mad_Malang  mad_Lumajang    mad_Jember  ...  \
# 0  46682.222222  117469.333333  59356.111111  36432.000000  80062.777778  ...
# ...

# %%
def totalmad (mad):
    total_mad = (Hasil_mad['mad_'+mad]).mean()         

    return total_mad

# %%
totalmad = {'KabPacitan' : (Hasil_mad['mad_KabPacitan'].mean()),
            'KabPonorogo' : (Hasil_mad['mad_KabPonorogo'].mean()),
            'Trenggalek' : (Hasil_mad['mad_Trenggalek'].mean()),
            'Tulungagung' : (Hasil_mad['mad_Tulungagung'].mean()),
            'Blitar' : (Hasil_mad['mad_Blitar'].mean()),
            'Kediri' : (Hasil_mad['mad_Kediri'].mean()),
            'Malang' : (Hasil_mad['mad_Malang'].mean()),
            'Lumajang' : (Hasil_mad['mad_Lumajang'].mean()),
            'Jember' : (Hasil_mad['mad_Jember'].mean()),
            'Banyuwangi' : (Hasil_mad['mad_Banyuwangi'].mean()),
            'Bondowoso' : (Hasil_mad['mad_Bondowoso'].mean()),
            'Situbondo' : (Hasil_mad['mad_Situbondo'].mean()),
            'Probolinggo' : (Hasil_mad['mad_Probolinggo'].mean()),
            'Pasuruan' : (Hasil_mad['mad_Pasuruan'].mean()),
            'Sidoarjo' : (Hasil_mad['mad_Sidoarjo'].mean()),
            'Mojokerto' : (Hasil_mad['mad_Mojokerto'].mean()),
            'Jombang' : (Hasil_mad['mad_Jombang'].mean()),
            'Nganjuk' : (Hasil_mad['mad_Nganjuk'].mean()),
            'Madiun' : (Hasil_mad['mad_Madiun'].mean()),
            'Magetan' : (Hasil_mad['mad_Magetan'].mean()),
            'Ngawi' : (Hasil_mad['mad_Ngawi'].mean()),
            'Bojonegoro' : (Hasil_mad['mad_Bojonegoro'].mean()),
            'Tuban' : (Hasil_mad['mad_Tuban'].mean()),
            'Lamongan' : (Hasil_mad['mad_Lamongan'].mean()),
            'Gresik' : (Hasil_mad['mad_Gresik'].mean()),
            'Bangkalan' : (Hasil_mad['mad_Bangkalan'].mean()),
            'Sampang' : (Hasil_mad['mad_Sampang'].mean()),
            'Pamekasan' : (Hasil_mad['mad_Pamekasan'].mean()),
            'Sumenep' : (Hasil_mad['mad_Sumenep'].mean()),
            'KediriKota' : (Hasil_mad['mad_KediriKota'].mean()),
            'BlitarKota' : (Hasil_mad['mad_BlitarKota'].mean()),
            'MalangKota' : (Hasil_mad['mad_MalangKota'].mean()),
            'ProbolinggoKota' : (Hasil_mad['mad_ProbolinggoKota'].mean()),
            'PasuruanKota' : (Hasil_mad['mad_PasuruanKota'].mean()),
            'MojokertoKota' : (Hasil_mad['mad_MojokertoKota'].mean()),
            'MadiunKota' : (Hasil_mad['mad_MadiunKota'].mean()),
            'Surabaya' : (Hasil_mad['mad_Surabaya'].mean()),
            'Batu' : (Hasil_mad['mad_Batu'].mean())
           }
    
total_mad = pd.DataFrame(totalmad, index=[0])
total_mad
# Out:
#     KabPacitan  KabPonorogo   Trenggalek  Tulungagung        Blitar  \
# 0  4395.777778  3124.851852  2915.790123  8821.395062  16582.888889
#
#         Kediri       Malang      Lumajang        Jember   Banyuwangi  ...  \
# 0  28151.62963  16884.82716  12660.037037  23496.074074  9452.654321  ...
#
#        Sumenep  KediriKota  BlitarKota  MalangKota  ProbolinggoKota  \
# 0  6139.098765  876.703704  230.407407  570.888889        455.17284
#
#    PasuruanKota  MojokertoKota  MadiunKota    Surabaya        Batu
# 0     91.567901      47.506173   26.239075  211.765432  198.975309
#
# [1 rows x 38 columns]

# %%
totalmad = total_mad.T #transpose data
hasilakhirmad = totalmad[0].mean()
print ("hasil akhir mad adalah =", hasilakhirmad)
# Out:
# hasil akhir mad adalah = 7423.979975645867
